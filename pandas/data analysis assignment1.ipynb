# %%
import pandas as pd

# %% [markdown]
# # Create a data frame which contains name and age of workshop participants(random age)-both dictionary and list

# %%
import random

# %% [markdown]
# FROM DICTIONARY

# %%
cricket_workshop={'name':["kohli","dhoni","sachin",'rohit'],'age':[random.randint(30,50) for i in range(4)]}

# %%
pd.DataFrame(cricket_workshop)
# Out:
#      name  age
# 0   kohli   46
# 1   dhoni   38
# 2  sachin   48
# 3   rohit   41

# %% [markdown]
# FROM A LIST OF TUPLES

# %%
participants=[
    ('sachin', random.randint(20, 50)),
    ('kohli', random.randint(20, 50)),
    ('dhoni', random.randint(20, 50)),
    ('rohit', random.randint(20, 50))]

# %%
pd.DataFrame(participants,columns=['Name','Age'])
# Out:
#      Name  Age
# 0  sachin   29
# 1   kohli   41
# 2   dhoni   42
# 3   rohit   49

# %% [markdown]
# # Read 5 different data sets and perform basics tasks

# %% [markdown]
# 1:JOB PLACEMENT from kaggle

# %%
a=pd.read_csv("job_placement.csv")
a
# Out:
#       id             name  gender  age      degree  \
# 0      1         John Doe    Male   25  Bachelor's
# 1      2       Jane Smith  Female   24  Bachelor's
# 2      3  Michael Johnson    Male   26  Bachelor's
# 3      4      Emily Davis  Female   23  Bachelor's
# 4      5      David Brown    Male   24  Bachelor's
# ..   ...              ...     ...  ...         ...
# 695  696     Lucas Taylor    Male   23  Bachelor's
# 696  697    Emma Martinez  Female   26  Bachelor's
# 697  698      Aiden Davis    Male   24  Bachelor's
# 698  699       Mia Wilson  Female   23  Bachelor's
# 699  700      Jack Garcia    Male   26  Bachelor's
#
#                             stream                               college_name  \
# 0                 Computer Science                         Harvard University
# 1           Electrical Engineering      Massachusetts Institute of Technology
# 2           Mechanical Engineering                        Stanford University
# ...

# %%
a.size
# Out:
# 7700

# %%
a.shape
# Out:
# (700, 11)

# %%
a.columns
# Out:
# Index(['id', 'name', 'gender', 'age', 'degree', 'stream', 'college_name',
#        'placement_status', 'salary', 'gpa', 'years_of_experience'],
#       dtype='object')

# %%
a.head()
# Out:
#    id             name  gender  age      degree                  stream  \
# 0   1         John Doe    Male   25  Bachelor's        Computer Science
# 1   2       Jane Smith  Female   24  Bachelor's  Electrical Engineering
# 2   3  Michael Johnson    Male   26  Bachelor's  Mechanical Engineering
# 3   4      Emily Davis  Female   23  Bachelor's  Information Technology
# 4   5      David Brown    Male   24  Bachelor's        Computer Science
#
#                             college_name placement_status  salary  gpa  \
# 0                     Harvard University           Placed   60000  3.7
# 1  Massachusetts Institute of Technology           Placed   65000  3.6
# 2                    Stanford University           Placed   58000  3.8
# 3                        Yale University       Not Placed       0  3.5
# 4                   Princeton University           Placed   62000  3.9
#
#    years_of_experience
# 0                  2.0
# 1                  1.0
# 2                  3.0
# ...

# %%
a.tail()
# Out:
#       id           name  gender  age      degree  \
# 695  696   Lucas Taylor    Male   23  Bachelor's
# 696  697  Emma Martinez  Female   26  Bachelor's
# 697  698    Aiden Davis    Male   24  Bachelor's
# 698  699     Mia Wilson  Female   23  Bachelor's
# 699  700    Jack Garcia    Male   26  Bachelor's
#
#                             stream                               college_name  \
# 695               Computer Science                   University of Washington
# 696  Electronics and Communication         University of California--Berkeley
# 697               Computer Science   University of Illinois--Urbana-Champaign
# 698         Electrical Engineering            University of Colorado--Boulder
# 699         Information Technology  University of North Carolina--Chapel Hill
#
#     placement_status  salary  gpa  years_of_experience
# 695           Placed   67000  3.8                  3.0
# 696           Placed   66000  3.9                  3.0
# ...

# %% [markdown]
# 2: TOURISM ARRIVALS from data.gov.in

# %%
b=pd.read_csv("Chapter_26_Tourism-Table_26.2-Rankwise_Calculation.csv")
b
# Out:
#    Name of Countries     2001     2002     2003     2004     2005     2006  \
# 0                USA   329147   348182   410803   526120   611165   696739
# 1                 UK   405472   387846   430917   555907   651803   734240
# 2         BANGLADESH   431312   435867   454611   477446   456371   484401
# 3           SRILANKA   112813   108008   109098   128711   136400   154813
# 4             CANADA    88600    93598   107671   135884   157643   176567
# 5             FRANCE   102434    78194    97654   131824   152258   175345
# 6            GERMANY    80011    64891    76868   116679   120243   156808
# 7              JAPAN    80634    59709    77996    96851   103082   119292
# 8          AUSTRALIA    52691    50743    58730    81608    96258   109867
# 9           MALAYSIA    57869    63748    70750    84390    96276   107286
# 10         SINGAPORE    42824    44306    48368    60710    68666    82574
# ...

# %%
b.size
# Out:
# 320

# %%
b.shape
# Out:
# (20, 16)

# %%
b.columns
# Out:
# Index(['Name of Countries', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015'],
#       dtype='object')

# %%
b.head()
# Out:
#   Name of Countries    2001    2002    2003    2004    2005    2006    2007  \
# 0               USA  329147  348182  410803  526120  611165  696739  799062
# 1                UK  405472  387846  430917  555907  651803  734240  796191
# 2        BANGLADESH  431312  435867  454611  477446  456371  484401  480240
# 3          SRILANKA  112813  108008  109098  128711  136400  154813  204084
# 4            CANADA   88600   93598  107671  135884  157643  176567  208214
#
#      2008    2009    2010    2011     2012     2013     2014     2015
# 0  804933  827140  931292  980688  1039947  1085309  1118983  1213624
# 1  776530  769251  759494  798249   788170   809444   942562   867601
# 2  541884  468899  431962  463543   487397   524923   838860  1133879
# 3  218805  239995  266515  305853   296983   262345   301601   299513
# 4  222364  224069  242372  259017   256021   255222   268485   281306

# %%
b.tail()
# Out:
#    Name of Countries     2001     2002     2003     2004     2005     2006  \
# 15          Thailand    18623    19789    26273    33442    41978    46623
# 16             Nepal    41135    43758    43597    53207    77024    91552
# 17          Pakistan    52762     2946    10364    67416    88609    83426
# 18            Others   543399   545751   641792   798579   841954   952716
# 19             Total  2537282  2384364  2726214  3456698  3918610  4447167
#
#        2007     2008     2009     2010     2011     2012     2013     2014  \
# 15    50037    58065    67309    76617    92404   105141   117136   121362
# 16    83037    78133    88785   104374   119131   125375   113790   126416
# 17   106283    85529    53137    51739    48640    59846   111794    96434
# 18  1136453  1224252  1193023  1402880  1560605  1619293  1721930  1857843
# 19  5081504  5282603  5167699  5775692  6309222  6577745  6967601  7679099
#
#        2015
# 15   115860
# 16   154720
# 17   124924
# ...

# %% [markdown]
# 3: CRICKET RANKINGS from espncricinfo.com

# %%
c=pd.read_excel('Petroleum-Price-Analysis/petroleum_dataset.xlsx')
c
# Out:
#                    Date  Petroleume price in PKR  Diesel Dollar rate  \
# 0   2023-02-16 00:00:00                   272.00  280.00         268
# 1   2023-01-31 00:00:00                   249.80  262.80      267.99
# 2   2023-01-29 00:00:00                   249.80  262.80      250.62
# 3   2023-01-16 00:00:00                   214.80  227.80      231.76
# 4   2023-01-01 00:00:00                   214.80  227.80      226.53
# 5   2022-12-16 00:00:00                   214.80  227.80      225.05
# 6   2022-12-01 00:00:00                   224.80  235.30      223.64
# 7   2022-11-16 00:00:00                   224.80  235.30      222.28
# 8   2022-11-01 00:00:00                   224.80  235.30      220.54
# 9   2022-10-16 00:00:00                   224.80  235.30      218.67
# 10  2022-10-01 00:00:00                   224.80  235.30     228.10
# 11  2022-09-21 00:00:00                   237.43  247.43      239.92
# 12  2022-09-01 00:00:00                   235.98  247.43      218.06
# ...

# %%
c.size
# Out:
# 864

# %%
c.shape
# Out:
# (72, 12)

# %%
c.columns
# Out:
# Index(['Date', 'Petroleume price in PKR', 'Diesel', 'Dollar rate',
#        'Difference between diesl & PKR petrol', 'Inidian currency',
#        'Turkish currency', 'Saudia Riyal', 'China', 'Afghanistan',
#        'Bangladesh', 'Russia'],
#       dtype='object')

# %%
c.head()
# Out:
#                   Date  Petroleume price in PKR  Diesel Dollar rate  \
# 0  2023-02-16 00:00:00                    272.0   280.0         268
# 1  2023-01-31 00:00:00                    249.8   262.8      267.99
# 2  2023-01-29 00:00:00                    249.8   262.8      250.62
# 3  2023-01-16 00:00:00                    214.8   227.8      231.76
# 4  2023-01-01 00:00:00                    214.8   227.8      226.53
#
#    Difference between diesl & PKR petrol  Inidian currency  Turkish currency  \
# 0                                    8.0              3.28             14.32
# 1                                   13.0              3.28             14.32
# 2                                   13.0              3.22             13.32
# 3                                   13.0              2.82             12.18
# 4                                   13.0              2.74             12.12
#
#    Saudia Riyal  China  Afghanistan  Bangladesh  Russia
# ...

# %%
c.tail()
# Out:
#                    Date  Petroleume price in PKR  Diesel Dollar rate  \
# 67  2020-05-01 00:00:00                    81.58   80.15      159.75
# 68            25/3/2020                    96.58  107.25       158.3
# 69  2020-01-03 00:00:00                   111.59  122.25       153.7
# 70  2020-01-02 00:00:00                   116.60  127.26      154.25
# 71  2020-01-01 00:00:00                   116.60  127.26      154.25
#
#     Difference between diesl & PKR petrol  Inidian currency  Turkish currency  \
# 67                                  -1.43              2.11             22.78
# 68                                  10.67              2.18             24.86
# 69                                  10.66              2.08             24.67
# 70                                  10.66              2.16             25.82
# 71                                  10.66              2.18             25.81
#
#     Saudia Riyal  China  Afghanistan  Bangladesh  Russia
# ...

# %% [markdown]
# 4: TITANIC SURVIVORS LIST from github

# %%
d=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
d.size
# Out:
# 10692

# %%
d.shape
# Out:
# (891, 12)

# %%
d.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
d.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
d.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# 5: PLAIN CRASH DETAILS from github

# %%
e=pd.read_csv("https://raw.githubusercontent.com/ghostiek/PlaneCrashes/634e54c8f4a9d623630418520aef677e27cde119/CSV/Planecrashes.csv")
e
# Out:
#             Date   Time                                           Location  \
# 0      9/17/1908  17:18                                Fort Myer, Virginia
# 1      7/12/1912   6:30                            AtlantiCity, New Jersey
# 2       8/6/1913    NaN                 Victoria, British Columbia, Canada
# 3       9/9/1913  18:30                                 Over the North Sea
# 4     10/17/1913  10:30                         Near Johannisthal, Germany
# 5       3/5/1915   1:00                                    Tienen, Belgium
# 6       9/3/1915  15:20                              Off Cuxhaven, Germany
# 7      7/28/1916    NaN                              Near Jambol, Bulgeria
# 8      9/24/1916   1:00                                Billericay, England
# 9      10/1/1916  23:45                               Potters Bar, England
# 10    11/21/1916    NaN                                     Mainz, Germany
# ...

# %%
e.size
# Out:
# 68484

# %%
e.shape
# Out:
# (5268, 13)

# %%
e.columns
# Out:
# Index(['Date', 'Time', 'Location', 'Operator', 'Flight #', 'Route', 'Type',
#        'Registration', 'serialnumber', 'Aboard', 'Fatalities', 'Ground',
#        'Summary'],
#       dtype='object')

# %%
e.head()
# Out:
#          Date   Time                            Location  \
# 0   9/17/1908  17:18                 Fort Myer, Virginia
# 1   7/12/1912   6:30             AtlantiCity, New Jersey
# 2    8/6/1913    NaN  Victoria, British Columbia, Canada
# 3    9/9/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration serialnumber  Aboard  Fatalities  Ground  \
# 0          NaN            1     2.0         1.0     0.0
# 1          NaN          NaN     5.0         5.0     0.0
# ...

# %%
e.tail()
# Out:
#            Date  Time                                           Location  \
# 5263  5/20/2009  6:30                             Near Madiun, Indonesia
# 5264  5/26/2009   NaN                  Near Isiro, DemocratiRepubliCongo
# 5265   6/1/2009  0:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266   6/7/2009  8:30       Near Port Hope Simpson, Newfoundland, Canada
# 5267   6/8/2009   NaN                  State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# 5263  Military - Indonesian Air Force      NaN
# 5264                      Service Air      NaN
# 5265                       Air France      447
# 5266                       Strait Air      NaN
# 5267      Military - Indian Air Force      NaN
#
#                                           Route  \
# 5263                           Jakarta - Maduin
# 5264                               Goma - Isiro
# 5265                     Rio de Janeiro - Paris
# ...

# %% [markdown]
# # Write a csv from tsv and excel

# %% [markdown]
# # TSV TO CSV

# %%
w=pd.read_table("pandas_docs/test.tsv")
w
# Out:
#                     test     test   test.1   test.2  test.3
# Magnus  Magnus    Magnus   Magnus   Magnus   Magnus     NaN
# Carlsen Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %%
w.to_csv('chessmasters.csv')

# %%
pd.read_csv("chessmasters.csv")
# Out:
#   Unnamed: 0 Unnamed: 1     test     test   test.1   test.2  test.3
# 0     Magnus     Magnus   Magnus   Magnus   Magnus   Magnus     NaN
# 1    Carlsen    Carlsen  Carlsen  Carlsen  Carlsen  Carlsen     NaN

# %% [markdown]
# # EXCEL TO CSV

# %%
z=pd.read_excel("pandas_docs/excel_demo.xlsx")
z
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
z.to_csv("excel_demo.csv")
